# %% [markdown]
# #  <h1 align="center">Descriptive Analysis</h1>

# %% [markdown]
# ## 1 . Glucose Level Distribution: How much time do patients spend in Hypoglycemia, Normal, and Hyperglycemia zones?

# %% [markdown]
# #### Why I chose this Biomarker: Glucose is the core clinical variable in a diabetes dataset. It directly measures how well blood sugar is being controlled.
# #### Why it's important to the medical condition: T1DM patients must maintain glucose between 70–180 mg/dL. Time spent outside this range especially in hypoglycemia (<70) which is dangerous and life-threatening. This analysis reveals which patients have the poorest glucose control.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np

df = pd.read_csv(
    r"C:\Users\vidya\OneDrive\Desktop\DATA ANALYST\NUMPY NINJA\GITHUB\Team2_-PyQueens_-Python-Hackathon-_MAY-2026\Final cleaned csv files\Final cleaned csv files\Team2_PyQueens_Final_Cleaned_File.csv"
)

# ── Classify Glucose Zones ────────────────────────────────────────────────────
def classify_glucose(g):
    if g < 70:
        return 'Hypoglycemia'
    elif g <= 180:
        return 'Normal'
    else:
        return 'Hyperglycemia'

df['Glucose_Zone'] = df['Glucose'].apply(classify_glucose)

# ── Zone Colors ───────────────────────────────────────────────────────────────
zone_colors = {
    'Hypoglycemia'  : '#FF4C4C',
    'Normal'        : '#2ECC71',
    'Hyperglycemia' : '#FF9F1C'
}

# ── Overall Distribution ──────────────────────────────────────────────────────
zone_counts = df['Glucose_Zone'].value_counts()
zone_pct    = (zone_counts / len(df) * 100).round(2)

# ── Per Patient Breakdown ─────────────────────────────────────────────────────
patient_zone = (
    df.groupby(['Patient_Id', 'Glucose_Zone'])
    .size()
    .unstack(fill_value=0)
)
patient_zone_pct = (
    patient_zone.div(patient_zone.sum(axis=1), axis=0) * 100
).round(2)

for col in ['Hypoglycemia', 'Normal', 'Hyperglycemia']:
    if col not in patient_zone_pct.columns:
        patient_zone_pct[col] = 0
patient_zone_pct = patient_zone_pct[['Hypoglycemia', 'Normal', 'Hyperglycemia']]

# ── FIGURE ────────────────────────────────────────────────────────────────────
fig, axes = plt.subplots(1, 2, figsize=(18, 8))
fig.patch.set_facecolor('#F8F6FF')

# ── Donut Chart ───────────────────────────────────────────────────────────────
wedge_colors = [zone_colors[z] for z in zone_pct.index]
wedges, texts, autotexts = axes[0].pie(
    zone_pct.values,
    labels=zone_pct.index,
    autopct='%1.1f%%',
    colors=wedge_colors,
    startangle=90,
    pctdistance=0.75,
    wedgeprops=dict(width=0.55, edgecolor='white', linewidth=2)
)
for text in texts:
    text.set_fontsize(12)
    text.set_fontweight('bold')
for autotext in autotexts:
    autotext.set_fontsize(11)
    autotext.set_fontweight('bold')
    autotext.set_color('black')

axes[0].set_title('Overall Glucose Zone Distribution\n(All Patients Combined)',
                  fontsize=14, fontweight='bold', pad=20, color='#2C2C54')
axes[0].set_facecolor('#F8F6FF')
axes[0].text(0, 0, f'{len(df):,}\nReadings',
             ha='center', va='center',
             fontsize=12, fontweight='bold', color='#2C2C54')

# ── Stacked Bar Chart ─────────────────────────────────────────────────────────
bar_colors = [zone_colors[z] for z in ['Hypoglycemia', 'Normal', 'Hyperglycemia']]
patient_zone_pct.plot(
    kind='bar',
    stacked=True,
    color=bar_colors,
    ax=axes[1],
    edgecolor='white',
    linewidth=0.5,
    width=0.7,
    legend=False
)

# ── Add % Labels for High Risk Patients ───────────────────────────────────────
for i, patient in enumerate(patient_zone_pct.index):
    hypo_pct  = patient_zone_pct.loc[patient, 'Hypoglycemia']
    hyper_pct = patient_zone_pct.loc[patient, 'Hyperglycemia']

    # Hypoglycemia label — inside the red bar, rotated vertical
    if hypo_pct > 10:
        axes[1].text(
            i, hypo_pct / 2,
            f'{hypo_pct:.0f}%',
            ha='center', va='center',
            fontsize=10, fontweight='bold',
            color='black',
            rotation=90
        )

    # Hyperglycemia label — inside the orange bar, rotated vertical
    if hyper_pct > 40:
        normal_pct = patient_zone_pct.loc[patient, 'Normal']
        axes[1].text(
            i, hypo_pct + normal_pct + hyper_pct / 2,
            f'{hyper_pct:.0f}%',
            ha='center', va='center',
            fontsize=10, fontweight='bold',
            color='black',
            rotation=90
        )

axes[1].set_title('Glucose Zone % Per Patient',
                  fontsize=14, fontweight='bold', pad=20, color='#2C2C54')
axes[1].set_xlabel('Patient ID', fontsize=11, fontweight='bold', color='#2C2C54')
axes[1].set_ylabel('Percentage (%)', fontsize=11, fontweight='bold', color='#2C2C54')
axes[1].tick_params(axis='x', labelsize=7)
axes[1].set_xticklabels(patient_zone_pct.index, rotation=45, ha='right')
axes[1].set_facecolor('#F8F6FF')
axes[1].set_ylim(0, 108)              # ← increased to give space for labels above bars
axes[1].axhline(y=70, color='#2C2C54', linestyle='--', linewidth=1.2, alpha=0.7)
axes[1].spines[['top', 'right']].set_visible(False)

# ── Legend — Top Right Corner Outside Chart ───────────────────────────────────
patches = [mpatches.Patch(color=zone_colors[z], label=z)
           for z in ['Hypoglycemia', 'Normal', 'Hyperglycemia']]
axes[1].legend(
    handles=patches,
    loc='upper right',
    bbox_to_anchor=(1.0, 1.15),
    ncol=1,
    fontsize=9,
    framealpha=0.9,
    edgecolor='#2C2C54'
)

plt.suptitle('Question 1: Glucose Level Distribution Analysis',
             fontsize=16, fontweight='bold', color='#2C2C54', y=1.02)
plt.tight_layout()
plt.savefig(
    r"C:\Users\vidya\OneDrive\Desktop\DATA ANALYST\NUMPY NINJA\GITHUB\Team2_-PyQueens_-Python-Hackathon-_MAY-2026\Final cleaned csv files\Final cleaned csv files\Q1_Glucose_Distribution.png",
    dpi=150, bbox_inches='tight', facecolor='#F8F6FF'
)
plt.show()
print("Chart saved successfully!")

# ── Summary Stats ─────────────────────────────────────────────────────────────
print("\n=== Overall Glucose Zone Distribution ===")
for zone, pct in zone_pct.items():
    print(f"  {zone:15}: {round(pct, 1)}%")
    
most_at_risk = patient_zone_pct['Hypoglycemia'].idxmax()
print(f"\nMost at-risk patient : {most_at_risk} "
      f"({patient_zone_pct.loc[most_at_risk, 'Hypoglycemia']}% hypoglycemia)")
print(f"Best controlled      : {patient_zone_pct['Normal'].idxmax()} "
      f"({patient_zone_pct['Normal'].max()}% normal range)")
# Out:
# Chart saved successfully!
#
# === Overall Glucose Zone Distribution ===
#   Normal         : 71.7%
#   Hyperglycemia  : 21.7%
#   Hypoglycemia   : 6.6%
#
# Most at-risk patient : HUPA0002P (23.86% hypoglycemia)
# Best controlled      : HUPA0028P (88.79% normal range)

# %% [markdown]
# #### Insight:
# #### In doughnut chart Out of 309,392 total glucose readings across all 25 patients, 71.7% are in the safe normal range. However, 21.7% show high glucose (hyperglycemia) and 6.6% show dangerously low glucose (hypoglycemia) — meaning patients are spending nearly 30% of their time outside the safe zone.
# #### In Stacked Bar Chart High Hypoglycemia patients (red labels): HUPA0002P is the most at-risk patient with 24% of readings in the danger low zone  meaning 1 in every 4 readings was a potentially life-threatening low glucose episode. HUPA0018P (18%), HUPA0022P (15%), and HUPA016P (15%) also show alarmingly high hypoglycemia rates that need immediate clinical attention.
# #### High Hyperglycemia patients (orange labels): HUPA017P has the highest hyperglycemia at 62% — spending more than half their recorded time with dangerously high glucose. HUPA0009P (59%), HUPA014P and HUPA0020P (both around 52%) also show persistently elevated glucose levels that silently damage organs over time.
# #### Hence This analysis shows that while most patients maintain safe glucose levels most of the time, there are critical outliers on both ends patients dangerously low and dangerously high and these charts instantly tells us exactly who they are.

# %% [markdown]
# ## 2.What is the distribution of physical activity (steps and calories burned) across patients and how does it vary?

# %% [markdown]
# #### Why I Chose Steps and Calories as the Biomarker : Steps and calories are the only columns in this dataset that capture patient physical activity. Choosing both together gives a complete picture steps measure how much the patient moves, calories measure how hard they worked. No other team member has analysed these columns, making this a unique and valuable addition to the overall analysis.

# %% [markdown]
# #### Why it's important to the medical condition: Physical activity directly lowers blood sugar in diabetic patients  when they move, muscles absorb glucose naturally without insulin. Analysing steps and calories identifies sedentary patients who are at higher risk of persistent hyperglycemia and need lifestyle intervention alongside medication.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np

df = pd.read_csv(
    r"C:\Users\vidya\OneDrive\Desktop\DATA ANALYST\NUMPY NINJA\GITHUB\Team2_-PyQueens_-Python-Hackathon-_MAY-2026\Final cleaned csv files\Final cleaned csv files\Team2_PyQueens_Final_Cleaned_File.csv"
)

bg_color = '#F8F6FF'

# ── Per Patient Summary ───────────────────────────────────────────────────────
patient_stats = df.groupby('Patient_Id').agg(
    Avg_Steps    = ('Steps',    'mean'),
    Avg_Calories = ('Calories', 'mean')
).round(2).reset_index()

# Activity classification based on avg steps per 5-min interval
def classify_activity(steps):
    if steps < 20:
        return 'Sedentary'
    elif steps < 40:
        return 'Moderate'
    else:
        return 'Active'

patient_stats['Activity_Level'] = patient_stats['Avg_Steps'].apply(classify_activity)

activity_colors = {
    'Sedentary' : '#FF4C4C',
    'Moderate'  : '#FF9F1C',
    'Active'    : '#2ECC71'
}

patient_stats = patient_stats.sort_values('Avg_Steps', ascending=False).reset_index(drop=True)

# ── FIGURE ────────────────────────────────────────────────────────────────────
fig, axes = plt.subplots(1, 2, figsize=(20, 8))
fig.patch.set_facecolor(bg_color)

# ── CHART 1: Bubble Chart — Steps vs Calories per Patient ────────────────────
for _, row in patient_stats.iterrows():
    color  = activity_colors[row['Activity_Level']]
    size   = row['Avg_Calories'] * 60   # bubble size based on calories

    axes[0].scatter(
        row['Avg_Steps'],
        row['Avg_Calories'],
        s=size,
        color=color,
        alpha=0.75,
        edgecolors='white',
        linewidths=1.2
    )
    axes[0].annotate(
        row['Patient_Id'],
        (row['Avg_Steps'], row['Avg_Calories']),
        fontsize=6.5, ha='center', va='bottom',
        color='#2C2C54', fontweight='bold',
        xytext=(0, 8), textcoords='offset points'
    )

# Reference lines — activity thresholds
axes[0].axvline(x=20, color='#FF4C4C', linestyle='--',
                linewidth=1.2, alpha=0.7, label='Sedentary Threshold (20)')
axes[0].axvline(x=40, color='#2ECC71', linestyle='--',
                linewidth=1.2, alpha=0.7, label='Active Threshold (40)')

axes[0].set_title('Avg Steps vs Avg Calories Per Patient\n(Bubble Size = Calories Burned)',
                  fontsize=13, fontweight='bold', pad=20, color='#2C2C54')
axes[0].set_xlabel('Average Steps (per 5-min interval)',
                   fontsize=11, fontweight='bold', color='#2C2C54')
axes[0].set_ylabel('Average Calories Burned (kcal)',
                   fontsize=11, fontweight='bold', color='#2C2C54')
axes[0].set_facecolor(bg_color)
axes[0].spines[['top', 'right']].set_visible(False)

# Legend
patches = [mpatches.Patch(color=activity_colors[a], label=a)
           for a in ['Sedentary', 'Moderate', 'Active']]
line_handles = [
    plt.Line2D([0],[0], color='#FF4C4C', linestyle='--', lw=1.2, label='Sedentary Threshold (20)'),
    plt.Line2D([0],[0], color='#2ECC71', linestyle='--', lw=1.2, label='Active Threshold (40)')
]
axes[0].legend(
    handles=patches + line_handles,
    loc='upper right',
    bbox_to_anchor=(1.0, 1.13),
    ncol=1, fontsize=8,
    framealpha=0.9, edgecolor='#2C2C54'
)

# ── CHART 2: Stacked Horizontal Bar — Activity Profile Per Patient ────────────
# Calculate active vs sedentary time per patient
active_pct = (df.groupby('Patient_Id')
              .apply(lambda x: (x['Steps'] > 0).sum() / len(x) * 100)
              .round(2))
sedentary_pct = (100 - active_pct).round(2)

activity_df = pd.DataFrame({
    'Active'    : active_pct,
    'Sedentary' : sedentary_pct
}).loc[patient_stats['Patient_Id']]  # keep same sort order

bar_colors = ['#2ECC71', '#FF4C4C']
activity_df.plot(
    kind='barh',
    stacked=True,
    color=bar_colors,
    ax=axes[1],
    edgecolor='white',
    linewidth=0.5,
    width=0.7,
    legend=False
)

# Add % labels
for i, (patient, row) in enumerate(activity_df.iterrows()):
    active_val    = row['Active']
    sedentary_val = row['Sedentary']

    if active_val > 5:
        axes[1].text(
            active_val / 2, i,
            f'{active_val:.1f}%',
            ha='center', va='center',
            fontsize=6.5, fontweight='bold', color='white'
        )
    if sedentary_val > 5:
        axes[1].text(
            active_val + sedentary_val / 2, i,
            f'{sedentary_val:.1f}%',
            ha='center', va='center',
            fontsize=6.5, fontweight='bold', color='white'
        )

axes[1].set_title('Active vs Sedentary Time Per Patient\n(% of Total Recorded Time)',
                  fontsize=13, fontweight='bold', pad=20, color='#2C2C54')
axes[1].set_xlabel('Percentage (%)',
                   fontsize=11, fontweight='bold', color='#2C2C54')
axes[1].set_ylabel('Patient ID',
                   fontsize=11, fontweight='bold', color='#2C2C54')
axes[1].tick_params(axis='y', labelsize=8)
axes[1].set_xlim(0, 100)
axes[1].set_facecolor(bg_color)
axes[1].spines[['top', 'right']].set_visible(False)

# Legend outside
patches2 = [
    mpatches.Patch(color='#2ECC71', label='Active (Steps > 0)'),
    mpatches.Patch(color='#FF4C4C', label='Sedentary (Steps = 0)')
]
axes[1].legend(
    handles=patches2,
    loc='upper right',
    bbox_to_anchor=(1.0, 1.1),
    ncol=1, fontsize=8,
    framealpha=0.9, edgecolor='#2C2C54'
)

plt.suptitle('Question 3: Physical Activity Distribution — Steps & Calories Across Patients',
             fontsize=15, fontweight='bold', color='#2C2C54', y=1.02)
plt.tight_layout()
plt.savefig(
    r"C:\Users\vidya\OneDrive\Desktop\DATA ANALYST\NUMPY NINJA\GITHUB\Team2_-PyQueens_-Python-Hackathon-_MAY-2026\Final cleaned csv files\Final cleaned csv files\Q3_Physical_Activity.png",
    dpi=150, bbox_inches='tight', facecolor=bg_color
)
plt.show()
print("Chart saved successfully!")

# ── Summary Stats ─────────────────────────────────────────────────────────────
print("\n=== Physical Activity Summary ===")
print(f"Overall avg steps per 5-min    : {round(df['Steps'].mean(), 2)}")
print(f"Overall avg calories per 5-min : {round(df['Calories'].mean(), 2)}")
print(f"Sedentary readings (steps=0)   : {(df['Steps']==0).sum()} ({round((df['Steps']==0).mean()*100,1)}%)")
print(f"\nMost active patient  : {patient_stats.iloc[0]['Patient_Id']} "
      f"(avg {patient_stats.iloc[0]['Avg_Steps']} steps)")
print(f"Least active patient : {patient_stats.iloc[-1]['Patient_Id']} "
      f"(avg {patient_stats.iloc[-1]['Avg_Steps']} steps)")
print(f"\nActivity breakdown:")
print(patient_stats[['Patient_Id', 'Avg_Steps', 'Avg_Calories', 'Activity_Level']].to_string(index=False))
# Out:
# C:\Users\vidya\AppData\Local\Temp\ipykernel_444\4226964687.py:96: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: (x['Steps'] > 0).sum() / len(x) * 100)
# Chart saved successfully!
#
# === Physical Activity Summary ===
# Overall avg steps per 5-min    : 30.83
# Overall avg calories per 5-min : 8.81
# Sedentary readings (steps=0)   : 219350 (70.9%)
#
# Most active patient  : HUPA0024P (avg 56.31 steps)
# Least active patient : HUPA0005P (avg 13.48 steps)
#
# Activity breakdown:
# Patient_Id  Avg_Steps  Avg_Calories Activity_Level
#  HUPA0024P      56.31         13.30         Active
#  HUPA0011P      54.58          8.19         Active
#  HUPA0015P      47.73          7.60         Active
#  HUPA0026P      47.51          6.07         Active
#  HUPA0009P      47.35          8.21         Active
#  HUPA0007P      46.03         13.92         Active
#  HUPA0019P      45.73         10.99         Active
#  HUPA0010P      44.62          7.22         Active
#  HUPA0016P      43.74          8.60         Active
#  HUPA0002P      39.24         10.19       Moderate
#  HUPA0021P      38.16          6.69       Moderate
#  HUPA0020P      36.54         10.20       Moderate
#  HUPA0014P      35.65          7.31       Moderate
#  HUPA0018P      34.66          7.41       Moderate
#  HUPA0006P      34.01          9.84       Moderate
#  HUPA0004P      30.70         10.71       Moderate
#  HUPA0025P      27.83         11.83       Moderate
#  HUPA0017P      27.50          7.70       Moderate
#  HUPA0003P      27.41          9.32       Moderate
#  HUPA0027P      26.50          9.82       Moderate
#  HUPA0022P      20.07          7.77       Moderate
#  HUPA0001P      19.47          5.92      Sedentary
#  HUPA0028P      19.02          6.34      Sedentary
#  HUPA0023P      15.27          8.87      Sedentary
#  HUPA0005P      13.48          5.55      Sedentary
